# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Create a full scraping pipeline that involves traversing over many pages of a website, dealing with errors and storing data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
# Load the https://www.residentadvisor.net/events page in your browser.

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
# Open the inspect element feature in your browser

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
html_page = requests.get('https://www.residentadvisor.net/events/us/washingtonstate')

# %%
webpage = html_page.content
soup = BeautifulSoup(webpage, "html.parser")

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en,ja,es">
# <head id="_x1"><title>
# 	RA: Events in Washington State, United States of America
# </title><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="en,ja,es" http-equiv="content-language"/><meta content="RA: Resident Advisor" name="Description"/><meta content="RA, residentadvisor, resident, advisor, music, ra, events, in, washington, state, united, states, america" name="Keywords"/><meta content="Resident Advisor" name="Author"/><meta content="Resident Advisor" property="og:site_name"/><meta content="712773712080127" property="fb:app_id"/><link href="/bundles/default-css?v=FkfRVAlFvpndxqgZliJaJOXD-OhkiRFP8nrBK9Pg2R01" rel="stylesheet"/>
# <meta content="app-id=981952703, app-argument=ra-guide://search" name="apple-itunes-app"/><link href="/bundles/cat-listings-css?v=qgpSmyPbylOKeJFqy2yvCrTgAsw9yQYcJtLKS_vPO6s1" rel="stylesheet"/>
# <link href="/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/><link color="#000000" href="/images/ra_icon.svg" rel="mask-icon"/><script src="/bundles/default-js?v=3qaUNnKRH_PXCPLvCCsp5HpmkPv6G-3JQuMc2B329WA1"></script>
# <script>
# 	    googletag.cmd.push(function () { googletag.pubads().setTargeting("Page", "/events/us/washingtonstate").setTargeting("Category", "Listings").setTargeting("Section", "Events").setTargeting("Content", "EventsHome").setTargeting("Country", "US").setTargeting("Area", "WashingtonState"); });
#          console.info('Interested in our code? Join us and help write it - https://www.residentadvisor.net/about/jobs');
#     </script>
# <script>
#             const widthTest = false;
#         if (window.screen.availWidth < 663 && window.screen.width < window.screen.height && !widthTest) {
#             document.write('<meta name="viewport" content="width=328">');
#         } else {
#             document.write('<meta name="viewport" content="width=device-width, initial-scale=1">');
#         }
#     </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-940832047"></script>
# <script>
#             window.dataLayer = window.dataLayer || [];
#             function gtag() { dataLayer.push(arguments); }
#             gtag('js', new Date());
#
#             gtag('config', 'AW-940832047');
#         </script>
# <script src="/js/dist/ReactLibs.bundle.js?637163889129245442"></script>
# <script>
#             (function (w, d, s, l, i) {
#                 w[l] = w[l] || []; w[l].push({
#                     'gtm.start':
#                         new Date().getTime(), event: 'gtm.js'
#                 }); var f = d.getElementsByTagName(s)[0],
#                     j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                         'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#                     })(window, document, 'script', 'dataLayer', 'GTM-M269WMP');
#         </script>
# </head>
# <body id="body">
# <input id="user-id" name="user-id" type="hidden" value="0"/>
# <input id="see-ngc" name="see-ngc" type="hidden" value="false"/>
# <a name="top"></a>
# <header id="header">
# <div class="pnlLeaderWrapper">
# <div id="pnlLeader">
# <aside class="div-gpt-ad-1452773484957-6 leader"><div class="ad" id="div-gpt-ad-1452773484957-6"></div></aside>
# </div>
# </div>
# <nav class="clearfix" id="user">
# <ul style="-moz-user-select: -moz-none; -khtml-user-select: none; -webkit-user-select: none;">
# <li class="but dark arrow-down" id="basket">
# Basket
# <div class="count basket" style="display:none;"><span></span></div>
# </li>
# <li class="but dark desktop-only desktop-wide-only" id="nav-link"><a href="https://www.doorsopen.co/#utm_source=RA&amp;utm_medium=Header-link" target="_blank"><span>Music Jobs</span></a></li>
# <li class="but arrow-down temp login" id="profile">Login / Register</li>
# </ul>
# </nav>
# <ul class="bbox panel" id="profile-panel">
# <li><a href="https://www.residentadvisor.net/login">Login</a></li>
# <li><a href="https://www.residentadvisor.net/register">Register</a></li>
# </ul>
# <div class="bbox panel bbox generic clearfix" id="basket-panel">
# <div class="items"></div><div class="basket-but but myra"></div>
# </div>
# <div class="notificationPanel bbox clearfix events col3" id="notificationPanel"></div><div class="null" id="navContainer">
# <div id="navbar">
# <div id="logo"><a class="icon" href="/">Resident Advisor</a></div>
# <div class="modal-full-screen" id="search-bar">
# <span class="modal-close">×</span>
# <div class="modal-body" id="search-bar-internal">
# <span class="f24 mobile-only search-header">Search</span>
# <div id="search-box-div">
# <input id="search-box" placeholder="Artists, Clubs, Promoters, Cities" type="text"/>
# </div>
# <div class="but large" id="search-button">
# <a id="search" title="Search">Submit</a>
# </div>
# <div class="grey pt16 search-helper" style="display: none;">Did you mean</div>
# </div>
# </div>
# <nav class="modal-full-screen" id="nav" role="navigation">
# <div class="modal-close">×</div>
# <ul class="modal-body open" data-display="0" id="links">
# <li class="mobile-only tablet-off">
# <div id="logo-modal-nav">
# <a class="icon" ga-event-action="RA-Logo" ga-event-category="nav" ga-on="click" href="/">Resident Advisor</a>
# </div>
# </li>
# <li id="mMagazine">
# <span>
# Magazine</span>
# <ul>
# <li id="mNews"><a ga-event-action="News" ga-event-category="nav" ga-on="click" href="/news">
# News</a></li>
# <li id="mReviews"><a ga-event-action="Reviews" ga-event-category="nav" ga-on="click" href="/reviews.aspx">
# Reviews</a></li>
# <li id="mFeatures"><a ga-event-action="Features" ga-event-category="nav" ga-on="click" href="/features.aspx">
# Features</a></li>
# <li id="mFilms"><a ga-event-action="Videos" ga-event-category="nav" ga-on="click" href="/videos">
# Videos</a></li>
# </ul>
# </li>
# <li data-selected="1" id="mListings">
# <span>
# Listings</span>
# <ul>
# <li data-selected="1" id="mEvents"><a ga-event-action="Events" ga-event-category="nav" ga-on="click" href="/events">
# Events</a></li>
# <li id="mClubs"><a ga-event-action="Clubs" ga-event-category="nav" ga-on="click" href="/clubs.aspx">
# Clubs</a></li>
# <li id="mFestivals"><a ga-event-action="Festivals" ga-event-category="nav" ga-on="click" href="/festivals.aspx">
# Festivals</a></li>
# <li id="mPhotos"><a ga-event-action="Photos" ga-event-category="nav" ga-on="click" href="/photos.aspx">
# Photos</a></li>
# </ul>
# </li>
# <li id="mMusic">
# <span>
# Music</span>
# <ul>
# <li id="mDjpages"><a ga-event-action="Artists" ga-event-category="nav" ga-on="click" href="/dj.aspx">
# Artists</a></li>
# <li id="mMixOfTheDay"><a ga-event-action="Mix of the day" ga-event-category="nav" ga-on="click" href="/news/mix-of-the-day/2020/2">
# Mix of the day</a></li>
# <li id="mCharts"><a ga-event-action="DJ Charts" ga-event-category="nav" ga-on="click" href="/dj-charts.aspx">
# DJ Charts</a></li>
# <li id="mPodcast"><a ga-event-action="Podcasts" ga-event-category="nav" ga-on="click" href="/podcast.aspx">
# Podcasts</a></li>
# </ul>
# </li>
# <li data-url="https://search.residentadvisor.net/" id="mSearch">
# <a ga-event-action="reveal-desktop" ga-event-category="search" ga-on="click" href="#">
# Search</a>
# </li>
# </ul>
# </nav>
# <div ga-event-action="burger" ga-event-category="nav" ga-on="click" id="but-links">
# <div class="icon"></div>
# </div>
# <div ga-event-action="mobile-reveal" ga-event-category="search" ga-on="click" id="but-search">
# <div class="icon"></div>
# </div>
# </div>
# <div class="add-space" id="sectionHead">
# <h1>Events</h1>
# </div>
# <link href="/bundles/autocomplete-css?v=hX3EIxBPUes4W-JFrW9vc2V9eyRDs1p9rgi0LcnlXug1" rel="stylesheet"/>
# <script src="/bundles/autocomplete?v=SCtA5z9vnBIQK6ZI-wtyD14u0Lv-S6kQhwTW5lgrMYQ1"></script>
# <script src="/bundles/analytics-js?v=GRbOA-5b5S00wbAK8zMczxQRPgbblgKCy7f2bir0h281"></script>
# </div>
# <section class="clearfix" id="subnav">
# <ul>
# <li class="on" id="subnav-all"><a href="/events">All</a></li><li id="subnav-new"><a href="/events/new">New</a></li><li id="subnav-for-you"><a href="/events/favourites">For You</a></li><li id="subnav-promoters"><a href="/promoters.aspx">Promoters</a></li><li id="subnav-submit-an-event"><a href="/submit-event.aspx">Submit an event</a></li>
# </ul>
# </section>
# </header>
# <form action="./washingtonstate?cc=us&amp;an=washingtonstate" id="Form1" method="post">
# <div class="aspNetHidden">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="mRBAt8JJD+xjK1siGQRz6LgEJUvKBLThnKwKdGIVbdbKFkI0uXrJ5svv0gO20bN9NowqA9kZrmwlMV2EHqTGdEPD0w8="/>
# </div>
# <div class="aspNetHidden">
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="ADA4D364"/>
# </div>
# <main>
# <script src="/bundles/sticky-js?v=v676-NN9nrtj1Xpc3-lLALpuQvn14WLF-0HBUTbxEIQ1"></script>
# <script>
#     $(document).ready(function() {
#         $('.slide')
#         .scrollSnap({
#             page: 'eventshome'
#         });
#     })
#     </script>
# <ul class="content-list events-border">
# <li class="alt nobreak">
# <section class="content clearfix">
# <h1 class="listing-heading heading">Popular events in Washington State</h1>
# <div class="strip slide small" data-type="events" id="events-listing">
# <ul class="list small clearfix popular" style="padding: 0;">
# <li class="">
# <article class="highlight-top">
# <p>Fri, 7 Feb 2020</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1363662"><img class="nohide" src="/images/events/flyer/2020/2/us-0207-1363662-list.jpg"/></a>
# <p class="counter nohide">
# <span>10</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1363662">
# <h1>
# Secondnature feat. Simo Cell
# </h1>
# </a>
# <p class="copy nohide">
# TBA - Seattle
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Fri, 7 Feb 2020</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1374714"><img class="nohide" src="/images/events/flyer/2020/2/us-0207-1374714-list.jpg"/></a>
# <p class="counter nohide">
# <span>6</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1374714">
# <h1>
# Hunt &amp; Gather Winter Diversion: Doc Martin
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=88733">Kremwerk</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 8 Feb 2020</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1377215"><img class="nohide" src="/images/events/flyer/2020/2/us-0208-1377215-list.jpg"/></a>
# <p class="counter nohide">
# <span>4</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1377215">
# <h1>
# Physical Wash, Lower Tar, Chrome Corpse, Leash, Vox Sinistra
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=62614">Black Lodge</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Fri, 14 Feb 2020</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1376170"><img class="nohide" src="/images/events/flyer/2020/2/us-0214-1376170-list.jpg"/></a>
# <p class="counter nohide">
# <span>4</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1376170">
# <h1>
# Noise Complaint feat. Josh Wink + Two Nice Anniversary with Roska
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=88733">Kremwerk</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 15 Feb 2020</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1374711"><img class="nohide" src="/images/events/flyer/2020/2/us-0215-1374711-list.jpg"/></a>
# <p class="counter nohide">
# <span>9</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1374711">
# <h1>
# Depth: Aurora Halal with Archivist R.Pal B2B Todd Hochradel
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=88733">Kremwerk</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Thu, 20 Feb 2020</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1372103"><img class="nohide" src="/images/events/flyer/2020/2/us-0220-1372103-list.jpg"/></a>
# <p class="counter nohide">
# <span>5</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1372103">
# <h1>
# Haüsed: DJ Seinfeld
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=88733">Kremwerk</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Fri, 21 Feb 2020</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1379601"><img class="nohide" src="/images/events/flyer/dj/omars-list.jpg"/></a>
# <p class="counter nohide">
# <span>4</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1379601">
# <h1>
# Kremwerk 6 Year Anniversary Friday: Omar S [Research x Queer Dance Affair x Boyhood present]
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=88733">Kremwerk</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Fri, 28 Feb 2020</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1363169"><img class="nohide" src="/images/events/flyer/2020/2/us-0228-1363169-list.jpg"/></a>
# <p class="counter nohide">
# <span>5</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1363169">
# <h1>
# Shameless 17 Year Anniversary Party with DeWalta &amp; Residents
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=5613">Re-Bar</a>
# </p>
# </article>
# </li> </ul>
# </div>
# <div class="link-more mobile-only tablet-off">
# <a></a>
# </div>
# <script>
#                             googleAnalytics.sendEventDataOnLoad('events-page', 'popular-events-loaded');
#                        </script>
# </section>
# <section class="iOSOnly content">
# <ul class="phones">
# <li class="f12 pb4 grey">Want RA listings on your mobile?</li>
# <li>
# <div class="but"><a href="https://itunes.apple.com/app/apple-store/id981952703?mt=8">Download the RA Guide</a></div>
# </li>
# </ul>
# </section>
# <div class="banner clearfix">
# <div id="pnlECTOSlot1" style="text-align: center;">
# <div class="ad" id="div-gpt-ad-1452773484957-0"></div>
# </div>
# </div>
# </li>
# <li class="clearfix pt1">
# <div class="page-items content" id="previous-next">
# <ul>
# <li class="but arrow-left left" id="liPrevious">
# <a ga-event-action="Previous " ga-event-category="event-listings" ga-on="click" href="/events/us/washingtonstate/week/2020-01-28">Previous </a>
# </li><li class="but arrow-right right" id="liNext">
# <a ga-event-action="Next " ga-event-category="event-listings" ga-on="click" href="/events/us/washingtonstate/week/2020-02-11">Next </a>
# </li>
# </ul>
# </div>
# <div class="content clearfix">
# <div class="plus8">
# <div>
# <script src="/bundles/area-country-date-filter-js?v=Q02f5CsIXWPDeOtgJVocYJrwjcQrf96m1qneHFerLLA1"></script>
# <ul class="clearfix classic" data-enableevent="True" id="ulButtons">
# <li class="but arrow-down right" id="liCountry">
# <input id="hdnCountryId" name="ctl00$ctl00$cphContent$_contentmain$ucAreaCountryDateFilter$hdnCountryId" type="hidden" value="2"/>
# <span>US</span><input id="country-name" type="hidden" value="United States of America"/><ul class="links" style="display: none;"><li data-id="7"><a href="/events">Canada</a></li><li data-id="15"><a href="/events">France</a></li><li data-id="12"><a href="/events">Germany</a></li><li data-id="20"><a href="/events">Italy</a></li><li data-id="6"><a href="/events">Netherlands</a></li><li data-id="5"><a href="/events">Spain</a></li><li data-id="3"><a href="/events">United Kingdom</a></li><li class="selected" data-id="2"><a href="/events">United States of America</a></li><li data-id="0"><a href="/events">------------</a></li><li data-id="99"><a href="/events">Albania</a></li><li data-id="125"><a href="/events">Algeria</a></li><li data-id="113"><a href="/events">Andorra</a></li><li data-id="127"><a href="/events">Angola</a></li><li data-id="140"><a href="/events">Antigua and Barbuda</a></li><li data-id="16"><a href="/events">Argentina</a></li><li data-id="106"><a href="/events">Armenia</a></li><li data-id="1"><a href="/events">Australia</a></li><li data-id="57"><a href="/events">Austria</a></li><li data-id="108"><a href="/events">Azerbaijan</a></li><li data-id="117"><a href="/events">Bahamas</a></li><li data-id="80"><a href="/events">Bahrain</a></li><li data-id="107"><a href="/events">Bangladesh</a></li><li data-id="73"><a href="/events">Barbados</a></li><li data-id="76"><a href="/events">Belarus</a></li><li data-id="29"><a href="/events">Belgium</a></li><li data-id="34"><a href="/events">Belize</a></li><li data-id="141"><a href="/events">Benin</a></li><li data-id="126"><a href="/events">Bermuda</a></li><li data-id="142"><a href="/events">Bhutan</a></li><li data-id="85"><a href="/events">Bolivia</a></li><li data-id="74"><a href="/events">Bosnia and Herzegovina</a></li><li data-id="143"><a href="/events">Botswana</a></li><li data-id="28"><a href="/events">Brazil</a></li><li data-id="47"><a href="/events">Bulgaria</a></li><li data-id="144"><a href="/events">Burkina Faso</a></li><li data-id="110"><a href="/events">Cambodia</a></li><li data-id="145"><a href="/events">Cameroon</a></li><li data-id="7"><a href="/events">Canada</a></li><li data-id="92"><a href="/events">Cayman Islands</a></li><li data-id="25"><a href="/events">Chile</a></li><li data-id="30"><a href="/events">China</a></li><li data-id="59"><a href="/events">Colombia</a></li><li data-id="10"><a href="/events">Costa Rica</a></li><li data-id="146"><a href="/events">Cote d'Ivoire</a></li><li data-id="46"><a href="/events">Croatia</a></li><li data-id="102"><a href="/events">Cuba</a></li><li data-id="129"><a href="/events">Curacao</a></li><li data-id="82"><a href="/events">Cyprus</a></li><li data-id="49"><a href="/events">Czech Republic</a></li><li data-id="147"><a href="/events">Democratic Republic of the Congo</a></li><li data-id="51"><a href="/events">Denmark</a></li><li data-id="66"><a href="/events">Dominican Republic</a></li><li data-id="72"><a href="/events">Ecuador</a></li><li data-id="48"><a href="/events">Egypt</a></li><li data-id="54"><a href="/events">El Salvador</a></li><li data-id="71"><a href="/events">Estonia</a></li><li data-id="160"><a href="/events">Ethiopia</a></li><li data-id="158"><a href="/events">Fiji</a></li><li data-id="41"><a href="/events">Finland</a></li><li data-id="15"><a href="/events">France</a></li><li data-id="148"><a href="/events">Gambia</a></li><li data-id="75"><a href="/events">Georgia</a></li><li data-id="12"><a href="/events">Germany</a></li><li data-id="149"><a href="/events">Ghana</a></li><li data-id="103"><a href="/events">Gibraltar</a></li><li data-id="13"><a href="/events">Greece</a></li><li data-id="116"><a href="/events">Guam</a></li><li data-id="87"><a href="/events">Guatemala</a></li><li data-id="63"><a href="/events">Honduras</a></li><li data-id="39"><a href="/events">Hungary</a></li><li data-id="86"><a href="/events">Iceland</a></li><li data-id="58"><a href="/events">India</a></li><li data-id="37"><a href="/events">Indonesia</a></l ...
# </li>
# <li class="but arrow-down right" id="liArea">
# <input id="btnArea" name="ctl00$ctl00$cphContent$_contentmain$ucAreaCountryDateFilter$btnArea" style="display:none;" type="submit" value="">
# <input id="hdnAreaId" name="ctl00$ctl00$cphContent$_contentmain$ucAreaCountryDateFilter$hdnAreaId" type="hidden" value="411"/>
# <span>Washington State</span><ul class="links" style="display: none;"><li class="parent" data-id="108"><a href="/events">Alabama</a></li><li class="parent" data-id="109"><a href="/events">Alaska</a></li><li class="parent" data-id="102"><a href="/events">Arizona</a></li><li class="parent" data-id="110"><a href="/events">Arkansas</a></li><li class="parent" data-id="308"><a href="/events">California</a></li><li data-id="23"><a href="/events">   Los Angeles</a></li><li data-id="310"><a href="/events">   Sacramento</a></li><li data-id="309"><a href="/events">   San Diego</a></li><li data-id="218"><a href="/events">   San Francisco</a></li><li class="parent" data-id="82"><a href="/events">Colorado</a></li><li class="parent" data-id="111"><a href="/events">Connecticut</a></li><li class="parent" data-id="112"><a href="/events">Delaware</a></li><li class="parent" data-id="317"><a href="/events">Florida</a></li><li data-id="314"><a href="/events">   Jacksonville</a></li><li data-id="38"><a href="/events">   Miami</a></li><li data-id="315"><a href="/events">   Orlando</a></li><li data-id="316"><a href="/events">   Tampa Bay</a></li><li class="parent" data-id="64"><a href="/events">Georgia</a></li><li class="parent" data-id="133"><a href="/events">Hawaii</a></li><li class="parent" data-id="113"><a href="/events">Idaho</a></li><li class="parent" data-id="359"><a href="/events">Illinois</a></li><li data-id="17"><a href="/events">   Chicago</a></li><li class="parent" data-id="85"><a href="/events">Indiana</a></li><li class="parent" data-id="114"><a href="/events">Iowa</a></li><li class="parent" data-id="90"><a href="/events">Kansas</a></li><li class="parent" data-id="115"><a href="/events">Kentucky</a></li><li class="parent" data-id="65"><a href="/events">Louisiana</a></li><li class="parent" data-id="116"><a href="/events">Maine</a></li><li class="parent" data-id="117"><a href="/events">Maryland</a></li><li class="parent" data-id="79"><a href="/events">Massachusetts</a></li><li class="parent" data-id="360"><a href="/events">Michigan</a></li><li data-id="19"><a href="/events">   Detroit</a></li><li class="parent" data-id="81"><a href="/events">Minnesota</a></li><li class="parent" data-id="103"><a href="/events">Mississippi</a></li><li class="parent" data-id="118"><a href="/events">Missouri</a></li><li class="parent" data-id="119"><a href="/events">Montana</a></li><li class="parent" data-id="120"><a href="/events">Nebraska</a></li><li class="parent" data-id="47"><a href="/events">Nevada</a></li><li class="parent" data-id="121"><a href="/events">New Hampshire</a></li><li class="parent" data-id="48"><a href="/events">New Jersey</a></li><li class="parent" data-id="122"><a href="/events">New Mexico</a></li><li class="parent" data-id="8"><a href="/events">New York</a></li><li data-id="443"><a href="/events">   Buffalo/Rochester</a></li><li class="parent" data-id="123"><a href="/events">North Carolina</a></li><li class="parent" data-id="124"><a href="/events">North Dakota</a></li><li class="parent" data-id="84"><a href="/events">Ohio</a></li><li class="parent" data-id="104"><a href="/events">Oklahoma</a></li><li class="parent" data-id="410"><a href="/events">Oregon</a></li><li data-id="125"><a href="/events">   Portland</a></li><li class="parent" data-id="80"><a href="/events">Pennsylvania</a></li><li class="parent" data-id="127"><a href="/events">Rhode Island</a></li><li class="parent" data-id="105"><a href="/events">South Carolina</a></li><li class="parent" data-id="128"><a href="/events">South Dakota</a></li><li class="parent" data-id="72"><a href="/events">Tennessee</a></li><li class="parent" data-id="318"><a href="/events">Texas</a></li><li data-id="321"><a href="/events">   Austin</a></li><li data-id="319"><a href="/events">   Dallas/Fort Worth</a></li><li data-id="322"><a href="/events">   El Paso</a></li><li data-id="63"><a href="/events">   Houston</a></li><li data-id="320"><a href="/events">   San Antonio</a></li><li class="parent" data-id ...
# </input></li>
# <li class="but arrow-down right" id="liDate">
# <input id="btnDateRange" name="ctl00$ctl00$cphContent$_contentmain$ucAreaCountryDateFilter$btnDateRange" style="display:none;" type="submit" value=""/>
# <input id="hdnDateRange" name="ctl00$ctl00$cphContent$_contentmain$ucAreaCountryDateFilter$hdnDateRange" type="hidden" value="2"/>
# <span data-id="2">By week</span><ul class="links" style="display: none;"><li data-id="1"><a href="/events/us/washingtonstate/default/0-0-0">By day</a></li><li class="selected" data-id="2"><a href="/events/us/washingtonstate/default/0-0-0">By week</a></li><li data-id="3"><a href="/events/us/washingtonstate/default/0-0-0">By month</a></li></ul>
# </li>
# </ul>
# </div>
# <div class="fl col4" id="event-listing">
# <ul class="list" id="items">
# <li><p class="eventDate date"><a href="/events.aspx?ai=411&amp;v=day&amp;mn=2&amp;yr=2020&amp;dy=6"><span>Thu, 06 Feb 2020 /</span></a></p></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-02-06T00:00" itemprop="startDate">2020-02-06T00:00</time></span><a href="/events/1375259"><img height="76" src="/images/events/flyer/2020/2/us-0206-1375259-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1375259" itemprop="url" title="Event details of Field Trip 106: Dustycloud">Field Trip 106: Dustycloud</a> <span>at <a href="/club.aspx?id=68203">Q Nightclub</a>, <a href="/events.aspx?ai=46">Seattle</a></span></h1><div class="grey event-lineup">Dustycloud</div><p class="attending"><span>2</span> Attending</p></div></article></li><li><p class="eventDate date"><a href="/events.aspx?ai=411&amp;v=day&amp;mn=2&amp;yr=2020&amp;dy=7"><span>Fri, 07 Feb 2020 /</span></a></p></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-02-07T00:00" itemprop="startDate">2020-02-07T00:00</time></span><a href="/events/1363662"><img height="76" src="/images/events/flyer/2020/2/us-0207-1363662-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1363662" itemprop="url" title="Event details of Secondnature feat. Simo Cell">Secondnature feat. Simo Cell</a> <span>at <span class="grey" style="display:inline;">TBA - Seattle</span>, <a href="/events.aspx?ai=46">Seattle</a></span></h1><div class="grey event-lineup">Simo Cell, Ferg, Aos</div><p class="attending"><span>10</span> Attending</p></div></article></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-02-07T00:00" itemprop="startDate">2020-02-07T00:00</time></span><a href="/events/1374714"><img height="76" src="/images/events/flyer/2020/2/us-0207-1374714-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1374714" itemprop="url" title="Event details of Hunt &amp; Gather Winter Diversion: Doc Martin">Hunt &amp; Gather Winter Diversion: Doc Martin</a> <span>at <a href="/club.aspx?id=88733">Kremwerk</a>, <a href="/events.aspx?ai=46">Seattle</a></span></h1><div class="grey event-lineup">Doc Martin, Doza, Pezzner, Michael Manahan</div><p class="attending"><span>6</span> Attending</p></div></article></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-02-07T00:00" itemprop="startDate">2020-02-07T00:00</time></span><a href="/events/1373180"><img height="76" src="/images/events/flyer/2020/2/us-0207-1373180-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1373180" itemprop="url" title="Event details of Future Funktion V">Future Funktion V</a> <span>at <a href="/club.aspx?id=88733">Kremwerk</a>, <a href="/events.aspx?ai=46">Seattle</a></span></h1><div class="grey event-lineup">TIMBRE ROOM | Austin Robertson, Oxymoron, Parker Mills</div><p class="attending"><span>2</span> Attending</p></div></article></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-02-07T00:00" itemprop="startDate">2020-02-07T00:00</time></span><a href="/events/1375261"><img height="76" src="/images/events/flyer/2020/2/us-0207-1375261-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1375261" itemprop="url" title="Event details of Citrus Room 2-Year Anniversary: Sasha Marie">Citrus Room 2-Year Anniversary: Sasha Marie</a> <span>at <a href="/club.aspx?id=6 ...
# </ul>
# </div>
# <div class="fl col2" style="padding-top: 88px;">
# <div class="pr8 sticky">
# <section id="calendar">
# <div class="h-align">
# <h1 class="heading">Calendar</h1>
# </div>
# <div id="calendar-inner">
# <select id="ddlCalendarMonth" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$ddlCalendarMonth" style="width:104px;">
# <option value="12">December</option>
# <option value="11">November</option>
# <option value="10">October</option>
# <option value="9">September</option>
# <option value="8">August</option>
# <option value="7">July</option>
# <option value="6">June</option>
# <option value="5">May</option>
# <option value="4">April</option>
# <option value="3">March</option>
# <option selected="selected" value="2">February</option>
# <option value="1">January</option>
# </select>
# <select id="ddlCalendarYear" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$ddlCalendarYear">
# <option selected="selected" value="2020">2020</option>
# <option value="2019">2019</option>
# <option value="2018">2018</option>
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# <option value="2015">2015</option>
# <option value="2014">2014</option>
# <option value="2013">2013</option>
# <option value="2012">2012</option>
# <option value="2011">2011</option>
# <option value="2010">2010</option>
# <option value="2009">2009</option>
# <option value="2008">2008</option>
# <option value="2007">2007</option>
# <option value="2006">2006</option>
# <option value="2005">2005</option>
# <option value="2004">2004</option>
# <option value="2003">2003</option>
# </select>
# <select id="ddlCalendarType" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$ddlCalendarType" style="width:104px;">
# <option value="day">By day</option>
# <option selected="selected" value="week">By week</option>
# <option value="month">By month</option>
# </select>
# <input id="hfCalendarDayOfWeek" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$hfCalendarDayOfWeek" type="hidden" value="4"/>
# <table><tr><th>Sun</th><th>Mon</th><th>Tue</th><th>Wed</th><th>Thu</th><th>Fri</th><th>Sat</th></tr><tr><td><a class="day-off" href="/events/us/washingtonstate/week/2020-01-26">26</a></td><td><a class="day-off" href="/events/us/washingtonstate/week/2020-01-27">27</a></td><td><a class="day-off" href="/events/us/washingtonstate/week/2020-01-28">28</a></td><td><a class="day-off" href="/events/us/washingtonstate/week/2020-01-29">29</a></td><td><a class="day-off" href="/events/us/washingtonstate/week/2020-01-30">30</a></td><td><a class="day-off" href="/events/us/washingtonstate/week/2020-01-31">31</a></td><td><a href="/events/us/washingtonstate/week/2020-02-01">1</a></td></tr><tr><td><a href="/events/us/washingtonstate/week/2020-02-02">2</a></td><td><a href="/events/us/washingtonstate/week/2020-02-03">3</a></td><td><span class="day-current">4</span></td><td><a href="/events/us/washingtonstate/week/2020-02-05">5</a></td><td><a href="/events/us/washingtonstate/week/2020-02-06">6</a></td><td><a href="/events/us/washingtonstate/week/2020-02-07">7</a></td><td><a href="/events/us/washingtonstate/week/2020-02-08">8</a></td></tr><tr><td><a href="/events/us/washingtonstate/week/2020-02-09">9</a></td><td><a href="/events/us/washingtonstate/week/2020-02-10">10</a></td><td><a href="/events/us/washingtonstate/week/2020-02-11">11</a></td><td><a href="/events/us/washingtonstate/week/2020-02-12">12</a></td><td><a href="/events/us/washingtonstate/week/2020-02-13">13</a></td><td><a href="/events/us/washingtonstate/week/2020-02-14">14</a></td><td><a href="/events/us/washingtonstate/week/2020-02-15">15</a></td></tr><tr><td><a href="/events/us/washingtonstate/week/2020-02-16">16</a></td><td><a href="/events/us/washingtonstate/week/2020-02-17">17</a></td><td><a href="/events/us/washingtonstate/week/2020-02-18">18</a></td><td><a href="/events/us/washingtonstate/week/2020-02-19">19</a></td><td><a href="/events/us/washingtonstate/week/2020-02-20">20</a></td><td><a href="/events/us/washingtonstate/week/2020-02-21">21</a></td><td><a href="/events/us/washingtonstate/week/2020-02-22">22</a></td></tr><tr><td><a href="/events/us/washingtonstate/week/2020-02-23">23</a></td><td><a href="/events/us/washingtonstate/week/2020-02-24">24</a></td><td><a href="/events/us/washingtonstate/week/2020-02-25">25</a></td><td><a href="/events/us/washingtonstate/week/2020-02-26">26</a></td><td><a href="/events/us/washingtonstate/week/2020-02-27">27</a></td><td><a href="/events/us/washingtonstate/week/2020-02-28">28</a></td><td><a href="/events/us/washingtonstate/week/2020-02-29">29</a></td></tr></table>
# </div>
# <script type="text/javascript">
# 		$("#ddlCalendarMonth, #ddlCalendarYear, #ddlCalendarType").change(function () {
#             var aSearch = location.search.indexOf("&") > 0
#                 ? location.search.split('&')
#                 : "";
#
# 			var sQueryString;
#
#             var month = $('#ddlCalendarMonth').val().length === 2
#                 ? $('#ddlCalendarMonth').val()
#                 : "0" + $('#ddlCalendarMonth').val();
#
#             var day = $('#hfCalendarDayOfWeek').val().length === 2
#                 ? $('#hfCalendarDayOfWeek').val()
#                 : "0" + $('#hfCalendarDayOfWeek').val();
#
#             var area = $('#liArea span').text().toLowerCase() === 'all'
#                 ? ""
#                 : $('#liArea span').text();
#
#             var country = area === ''
#                 ? $('#country-name').val()
#                 : $('#liCountry span').text()
#
# 			sQueryString = "/events/"
#                 + country.replace(/[^A-Z0-9]/ig, '').toLowerCase() + "/"
#                 + area.replace(/[^A-Z0-9À-ž]/ig, '').toLowerCase().normalize("NFD").replace(/[\u0300-\u036f]/g, "") + "/"
#                 + $('#ddlCalendarType').val() + "/"
# 				+ $('#ddlCalendarYear').val() + "-"
#                 + month + "-"
# 				+ day;
#
# 			location.href = sQueryString;
# 		});
# 	</script>
# </section>
# <div class="banner">
# <div id="pnlMPU">
# <div class="ad" id="div-gpt-ad-1452773484957-7" style="width: 300px; min-height: 250px; padding-bottom: 10px;"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="fl col2 h-align-toplist">
# <div class="mr8">
# <section class="top-list generic events" id="toplist">
# <h1 class="heading">Top Washington State clubs</h1>
# <ul>
# <li><a ga-event-action="Kremwerk" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=88733">Kremwerk</a> /</li><li><a ga-event-action="Re-Bar" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=5613">Re-Bar</a> /</li><li><a ga-event-action="Q Nightclub" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=68203">Q Nightclub</a> /</li><li><a ga-event-action="Neumos" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=3715">Neumos</a> /</li><li><a ga-event-action="The Monkey Loft" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=84493">The Monkey Loft</a> /</li><li><a ga-event-action="Chop Suey" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=4383">Chop Suey</a> /</li><li><a ga-event-action="The Showbox" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=11363">The Showbox</a> /</li><li><a ga-event-action="Nectar Lounge" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=2730">Nectar Lounge</a> /</li><li><a ga-event-action="Baltic Room" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=6064">Baltic Room</a> /</li><li><a ga-event-action="Lo-Fi Gallery" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=10003">Lo-Fi Gallery</a> /</li><li><a ga-event-action="Trinity" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=2813">Trinity</a> /</li><li><a ga-event-action="Showbox SoDo" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=9459">Showbox SoDo</a> /</li>
# </ul>
# <div class="but"><a ga-event-action="see-more" ga-event-category="top-clubs" ga-on="click" href="/clubs.aspx?ai=411">More Washington State clubs</a></div>
# </section><section class="top-list generic events" id="toplist">
# <h1 class="heading">Top 20 regions</h1>
# <ul>
# <li><a ga-event-action="London" ga-event-category="top-regions" ga-on="click" href="/guide/uk/london">London, UK</a> /</li><li><a ga-event-action="Berlin" ga-event-category="top-regions" ga-on="click" href="/guide/de/berlin">Berlin, DE</a> /</li><li><a ga-event-action="New York" ga-event-category="top-regions" ga-on="click" href="/guide/us/newyork">New York, US</a> /</li><li><a ga-event-action="Amsterdam" ga-event-category="top-regions" ga-on="click" href="/guide/nl/amsterdam">Amsterdam, NL</a> /</li><li><a ga-event-action="Tokyo" ga-event-category="top-regions" ga-on="click" href="/guide/jp/tokyo">Tokyo, JP</a> /</li><li><a ga-event-action="Paris" ga-event-category="top-regions" ga-on="click" href="/guide/fr/paris">Paris, FR</a> /</li><li><a ga-event-action="Barcelona" ga-event-category="top-regions" ga-on="click" href="/guide/es/barcelona">Barcelona, ES</a> /</li><li><a ga-event-action="Los Angeles" ga-event-category="top-regions" ga-on="click" href="/guide/us/losangeles">Los Angeles, US</a> /</li><li><a ga-event-action="Manchester" ga-event-category="top-regions" ga-on="click" href="/guide/uk/manchester">Manchester, UK</a> /</li><li><a ga-event-action="San Francisco" ga-event-category="top-regions" ga-on="click" href="/guide/us/sanfrancisco">San Francisco, US</a> /</li><li><a ga-event-action="Madrid" ga-event-category="top-regions" ga-on="click" href="/guide/es/madrid">Madrid, ES</a> /</li><li><a ga-event-action="South + East" ga-event-category="top-regions" ga-on="click" href="/guide/uk/southeast">South + East, UK</a> /</li><li><a ga-event-action="Melbourne" ga-event-category="top-regions" ga-on="click" href="/guide/au/melbourne">Melbourne, AU</a> /</li><li><a ga-event-action="Ibiza" ga-event-category="top-regions" ga-on="click" href="/guide/es/ibiza">Ibiza, ES</a> /</li><li><a ga-event-action="Miami" ga-event-category="top-regions" ga-on="click" href="/guide/us/miami">Miami, US</a> /</li><li><a ga-event-action="Sydney" ga-event-category="top-regions" ga-on="click" href="/guide/au/sydney">Sydney, AU</a> /</li><li><a ga-event-action="Prague" ga-event-category="top-regions" ga-on="click" href="/guide/cz/prague">Prague, CZ</a> /</li><li><a ga-event-action="Glasgow" ga-event-category="top-regions" ga-on="click" href="/guide/uk/glasgow">Glasgow, UK</a> /</li><li><a ga-event-action="Leeds" ga-event-category="top-regions" ga-on="click" href="/guide/uk/leeds">Leeds, UK</a> /</li><li><a ga-event-action="Chicago" ga-event-category="top-regions" ga-on="click" href="/guide/us/chicago">Chicago, US</a> /</li>
# </ul>
# <div class="but"><a ga-event-action="see-more" ga-event-category="top-regions" ga-on="click" href="/events.aspx?show=all">More regions</a></div>
# </section><div id="pnlSkyscraper">
# <div class="ad mobile-off" id="div-gpt-ad-1452773484957-12" style="width: 160px; height: 600px;"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="page-items content sub clearfix">
# <ul>
# <li class="but arrow-left left" id="liPrevious2">
# <a ga-event-action="Previous " ga-event-category="event-listings" ga-on="click" href="/events/us/washingtonstate/week/2020-01-28">Previous </a>
# </li><li class="but arrow-right right" id="liNext2">
# <a ga-event-action="Next " ga-event-category="event-listings" ga-on="click" href="/events/us/washingtonstate/week/2020-02-11">Next </a>
# </li>
# </ul>
# </div>
# <div class="banner clearfix">
# <div id="pnlECTOSlot2" style="text-align: center;">
# <div class="ad" id="div-gpt-ad-1452773484957-1"></div>
# </div>
# </div>
# <br/>
# <span>01 /</span>
# </li>
# <li class="alt">
# <section class="content" id="popular-news">
# <h1 class="heading listing-heading">Most popular news</h1>
# <div class="but heading-more mobile-off">
# <a ga-event-action="see-more" ga-event-category="news" ga-on="click" href="/news">More news</a>
# </div>
# <div class="strip small slide" data-type="news" id="news-listing">
# <ul class="list">
# <li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 29 Jan 2020</p>
# <a href="/news/71806">
# <img class="thumb" src="/images/news/2020/alex-t-theodossiadis-obit-rip-leeds-uk-dj.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71806/?comments=1">Post a comment</a>
# </p><a href="/news/71806">
# <h1>UK DJ and Tribe Records clerk Alex T dies aged 25</h1>
# </a>
# <p class="copy">The Leeds-based selector passed away yesterday from a short illness.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Thu, 30 Jan 2020</p>
# <a href="/news/71808">
# <img class="thumb" src="/images/news/2020/alex-t-mix-of-the-day.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71808/?comments=1">Post a comment</a>
# </p><a href="/news/71808">
# <h1>Mix Of The Day: Alex T</h1>
# </a>
# <p class="copy">An hour of garage in memory of one of the UK's finest specialists.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 29 Jan 2020</p>
# <a href="/news/71735">
# <img class="thumb" src="/images/news/2020/70799fcb-9625-4b3e-8c21-65180345d934.jpeg"/>
# </a>
# <p class="comments light">
# <a href="/news/71735/?comments=1">Post a comment</a>
# </p><a href="/news/71735">
# <h1>Listen to RA's playlists of the music that defined the decade</h1>
# </a>
# <p class="copy">The best of 2010-19, all in one place.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Thu, 30 Jan 2020</p>
# <a href="/news/71823">
# <img class="thumb" src="/images/news/2020/tim-sweeney-beats-in-space-studio-wynu-save-cut.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71823/?comments=1">Post a comment</a>
# </p><a href="/news/71823">
# <h1>Tim Sweeney's Beats In Space radio show under threat</h1>
# </a>
# <p class="copy">WNYU has cut the beloved long-running broadcast by an hour, with only a week's notice.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 31 Jan 2020</p>
# <a href="/news/71835">
# <img class="thumb" src="/images/news/2020/nicolas-jaar-mix-new-ep.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71835/?comments=1">Post a comment</a>
# </p><a href="/news/71835">
# <h1>Nicolas Jaar releases new EP as Against All Logic with FKA twigs and Lydia Lunch</h1>
# </a>
# <p class="copy">It's out via his Other People label, which will also share a new LP, 2017 - 2019, on February 7th.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 31 Jan 2020</p>
# <a href="/news/71837">
# <img class="thumb" src="/images/news/2020/dixon-dc10-2020.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71837/?comments=1">Post a comment</a>
# </p><a href="/news/71837">
# <h1>Dixon's Ibiza residency, Transmoderna, moves to DC-10 for 2020 season</h1>
# </a>
# <p class="copy">It'll run on Fridays at the storied super club this summer.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Tue, 04 Feb 2020</p>
# <a href="/news/71849">
# <img class="thumb" src="/images/news/2020/houghton-2020-names.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71849/?comments=1">Post a comment</a>
# </p><a href="/news/71849">
# <h1>Houghton Festival reveals first names for 2020</h1>
# </a>
# <p class="copy">Ricardo Villalobos, Helena Hauff and more will play the August event, which cancelled last year's edition due to bad weather.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 29 Jan 2020</p>
# <a href="/news/71809">
# <img class="thumb" src="/images/news/2020/lost-village-uk-festival-2020-lineup-photo.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71809/?comments=1">Post a comment</a>
# </p><a href="/news/71809">
# <h1>UK festival Lost Village reveals 2020 lineup</h1>
# </a>
# <p class="copy">The Lincolnshire event returns over the late August bank holiday weekend with Four Tet, Honey Dijon, Bradley Zero, Peach and more.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Thu, 30 Jan 2020</p>
# <a href="/news/71826">
# <img class="thumb" src="/images/news/2020/avery-cortini-photo-lp.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71826/?comments=1">Post a comment</a>
# </p><a href="/news/71826">
# <h1>Daniel Avery and Alessandro Cortini collaborate on new album, Illusion Of Time</h1>
# </a>
# <p class="copy">The LP, which has been in the works for several years, is out in March via Phantasy Sound.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Thu, 30 Jan 2020</p>
# <a href="/news/71824">
# <img class="thumb" src="/images/news/2020/melt-festival-2020-lineup-photo.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71824/?comments=1">Post a comment</a>
# </p><a href="/news/71824">
# <h1>Melt Festival adds FKA twigs, DJ Koze for 2020</h1>
# </a>
# <p class="copy">A back-to-back from Palms Trax and Hunee has also been confirmed for the July festival.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Mon, 03 Feb 2020</p>
# <a href="/news/71843">
# <img class="thumb" src="/images/news/2020/lente-kabinet-2020-lineup.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71843/?comments=1">Post a comment</a>
# </p><a href="/news/71843">
# <h1>Dekmantel announces lineup for Lente Kabinet Festival 2020</h1>
# </a>
# <p class="copy">Fatima Yamaha, Palms Trax and Peach are among those scheduled to play the Amsterdam event in May.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Mon, 03 Feb 2020</p>
# <a href="/news/71846">
# <img class="thumb" src="/images/news/2020/oya-quarry-new-japan-festival-enso-2020-1.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71846/?comments=1">Post a comment</a>
# </p><a href="/news/71846">
# <h1>New Japanese experimental festival Ensō will take place in a former stone quarry</h1>
# </a>
# <p class="copy">Run by REITEN, the first edition will be held in Tochigi's Ōya History Museum from April 10th through 12th, 2020.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Thu, 30 Jan 2020</p>
# <a href="/news/71784">
# <img class="thumb" src="/images/news/2020/kahn-and-neek-having-sick-time-mansions-bliss-photo-credit-asia-ella.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71784/?comments=1">Post a comment</a>
# </p><a href="/news/71784">
# <h1>Kahn &amp; Neek reunite on new EP, (Having A Sick Time) In The Mansions Of Bliss</h1>
# </a>
# <p class="copy">Out on Boofy's Sector 7 Sounds label February 28th, it's the duo's first joint release in four years.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 31 Jan 2020</p>
# <a href="/news/71833">
# <img class="thumb" src="/images/news/2020/organik-festival-taiwan-second-round-lineup-2020.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71833/?comments=1">Post a comment</a>
# </p><a href="/news/71833">
# <h1>Organik Festival adds Powder, Aurora Halal for 2020</h1>
# </a>
# <p class="copy">Chee Shimizu, Konduku and Vril will also play in Taiwan this April.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 29 Jan 2020</p>
# <a href="/news/71815">
# <img class="thumb" src="/images/news/2020/overmono.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71815/?comments=1">Post a comment</a>
# </p><a href="/news/71815">
# <h1>Overmono remix Thom Yorke on new EP, POLY012</h1>
# </a>
# <p class="copy">The two tracks arrive on February 7th via Poly Kicks.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 29 Jan 2020</p>
# <a href="/news/71810">
# <img class="thumb" src="/images/news/2020/griessmuhle-events-moving.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71810/?comments=1">Post a comment</a>
# </p><a href="/news/71810">
# <h1>Closing Berlin club Griessmuehle announces temporary venues for upcoming events</h1>
# </a>
# <p class="copy">Wednesday and Thursday nights will move to Polyglon Club, while weekend slam poetry and cinema events will happen at Alte Münze.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Tue, 04 Feb 2020</p>
# <a href="/news/71854">
# <img class="thumb" src="/images/news/2020/ben-ufo.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71854/?comments=1">Post a comment</a>
# </p><a href="/news/71854">
# <h1>Mix Of The Day: Ben UFO</h1>
# </a>
# <p class="copy">The venerated DJ drops into The Lot Radio for a two-hour session.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 29 Jan 2020</p>
# <a href="/news/71813">
# <img class="thumb" src="/images/news/2020/acemoma.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71813/?comments=1">Post a comment</a>
# </p><a href="/news/71813">
# <h1>AceMo and MoMA Ready drop new AceMoMA album, A New Dawn</h1>
# </a>
# <p class="copy">The LP is out now on Haus Of Altr.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 29 Jan 2020</p>
# <a href="/news/71811">
# <img class="thumb" src="/images/news/2020/get-lost-miami-2020-visionquest-reunion.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71811/?comments=1">Post a comment</a>
# </p><a href="/news/71811">
# <h1>Visionquest to reunite at 24-hour Get Lost party in Miami</h1>
# </a>
# <p class="copy">The 15th edition of Damian Lazarus's party will go down in March with Carl Craig, Soul Clap and more.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 31 Jan 2020</p>
# <a href="/news/71838">
# <img class="thumb" src="/images/news/2020/sebastian-mullaert-natthall-album.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/71838/?comments=1">Post a comment</a>
# </p><a href="/news/71838">
# <h1>Sebastian Mullaert announces new album, Natthall, made with the Tonhalle Orchester Zürich</h1>
# </a>
# <p class="copy">The LP was inspired by the natural beauty of a park near Mullaert's Swedish hometown.</p>
# </article>
# </li> </ul>
# </div>
# <div class="link-more mobile-only tablet-off">
# <a ga-event-action="see-more" ga-event-category="news" ga-on="click" href="/news">More news</a>
# </div>
# </section>
# <span>02 /</span>
# </li>
# </ul>
# </main>
# </form>
# <footer class="clearfix"><ul class="content-list">
# <li>
# <div class="content clearfix">
# <div class="clearfix plus8">
# <div class="fl col2-3">
# <ul class="pb32">
# <li id="logo-footer"><a href="/">RA</a></li>
# <li class="f12 grey pt16">Copyright © 2020 Resident Advisor Ltd.</li>
# <li class="f12 grey">All rights reserved.</li>
# <li class="f12 grey"><a href="/privacy">Privacy</a> &amp; <a href="/terms">Terms</a></li>
# <li class="f12 grey"><a href="/cookiepolicy">Cookie Policy</a></li>
# </ul>
# </div>
# <div class="fl col4-5 pt60">
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Resident Advisor /</li> <li><a ga-event-action="about" ga-event-category="homefooter" ga-on="click" href="/about">About</a></li>
# <li><a ga-event-action="advertise" ga-event-category="homefooter" ga-on="click" href="/about/advertising">Advertise</a></li>
# <li><a ga-event-action="jobs" ga-event-category="homefooter" ga-on="click" href="https://www.doorsopen.co/company/12/resident-advisor/#utm_source=RA&amp;utm_medium=footer-link">Jobs</a></li>
# <li><a ga-event-action="raevents" ga-event-category="homefooter" ga-on="click" href="/features/3214">24/7</a></li>
# <li><a ga-event-action="store" ga-event-category="homefooter" ga-on="click" href="https://store.ra.co">RA Store</a></li>
# <li><br/></li> </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">RA Tickets /</li>
# <li><a ga-event-action="mytickets" ga-event-category="homefooter" ga-on="click" href="/shop/history">My Tickets</a></li>
# <li><a ga-event-action="ticketfaq" ga-event-category="homefooter" ga-on="click" href="/shop/faq">Ticketing FAQ</a></li>
# <li><a ga-event-action="resale" ga-event-category="homefooter" ga-on="click" href="/tickets/resale">Resale</a></li>
# <li><a ga-event-action="selltickets" ga-event-category="homefooter" ga-on="click" href="/tickets">Sell tickets on RA</a></li>
# <li><div class="myra but" style="width: 152px; margin-top: 50px;"><a class="submit-event" ga-event-action="submitevent" ga-event-category="homefooter" ga-on="click" href="/submit-event.aspx">Submit event</a></div></li>
# <li><br/></li>
# </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Apps /</li> <li><a ga-event-action="raguide" ga-event-category="homefooter" ga-on="click" href="/ra-guide">RA Guide</a></li>
# <li><a ga-event-action="ticketscanner" ga-event-category="homefooter" ga-on="click" href="/tickets/scanner">RA Ticket Scanner</a></li> </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Elsewhere /</li>
# <li><a ga-event-action="rayoutube" ga-event-category="homefooter" ga-on="click" href="http://www.youtube.com/user/residentadvisor?sub_confirmation=1">Watch on YouTube</a></li>
# <li><a ga-event-action="rafacebook" ga-event-category="homefooter" ga-on="click" href="http://www.facebook.com/residentadvisor">Follow on Facebook</a></li>
# <li><a ga-event-action="raapplemusic" ga-event-category="homefooter" ga-on="click" href="https://itunes.apple.com/gb/curator/resident-advisor/id996091687">Listen on Apple Music</a></li>
# <li><a ga-event-action="raspotify" ga-event-category="homefooter" ga-on="click" href="https://open.spotify.com/user/residentadvisor">Stream on Spotify</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="nobreak">
# <div class="content clearfix">
# <div class="clearfix plus8">
# <div class="fl col3">
# <a href="https://jp.residentadvisor.net/"><a href="https://jp.residentadvisor.net/">RA is also available in Japanese. 日本版</a></a>
# </div>
# <ul class="col1p5" id="social">
# <li class="ytb"><a ga-event-action="rayoutube" ga-event-category="homefooter" ga-on="click" href="http://www.youtube.com/residentadvisor">RA on YouTube</a></li>
# <li class="fcb"><a ga-event-action="rafacebook" ga-event-category="homefooter" ga-on="click" href="http://www.facebook.com/residentadvisor">RA on Facebook</a></li>
# <li class="twt"><a ga-event-action="ratwitter" ga-event-category="homefooter" ga-on="click" href="http://www.twitter.com/residentadvisor">RA on Twitter</a></li>
# <li class="ins"><a ga-event-action="rainstagram" ga-event-category="homefooter" ga-on="click" href="http://instagram.com/resident_advisor">RA on Instagram</a></li>
# <li class="snd"><a ga-event-action="rasoundcloud" ga-event-category="homefooter" ga-on="click" href="http://www.soundcloud.com/resident-advisor">RA on Soundcloud</a></li>
# </ul>
# </div>
# </div>
# </li>
# </ul></footer>
# <script type="text/javascript">
#         (function(i, s, o, g, r, a, m) {
#                                         i['GoogleAnalyticsObject'] = r;
#                                         i[r] = i[r] || function() {
#                                             (i[r].q = i[r].q || []).push(arguments)
#                                         }, i[r].l = 1 * new Date();
#                                         a = s.createElement(o), m = s.getElementsByTagName(o)[0];
#                                         a.async = 1;
#                                         a.src = g;
#                                         m.parentNode.insertBefore(a, m)
#                                     })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#                                     ga('create', 'UA-313318-1', 'residentadvisor.net'
#                                     );
#                                     ga('require', 'displayfeatures');
#                                     ga('send', 'pageview');
#                                     ga('require', 'eventTracker');
#
#         if (window.location.href.indexOf('.residentadvisor.net') >= 0 && window.location.pathname.indexOf('submit-event') === 0) {
# 	        (function(r, a, v, e, l, i, n) {
# 	            r[l] = r[l] || function() { (r[l].q = r[l].q || []).push(arguments) };
# 	            i = a.createElement(v);
# 	            i.async = i.defer = 1;
# 	            i.src = e;
# 	            a.body.appendChild(i)
# 	        })(window, document, 'script', 'https://cdn.ravelin.net/js/rvn-beta.min.js', 'ravelin');
# 	        ravelin('setApiKey', 'pk_live_Z6F2v32uJEQnwn46SLF7xdojmnOPLfAI');
#             ravelin('setCustomerId', '0');
#             ravelin('setCookieDomain', '.residentadvisor.net');
# 	    }
# 	</script>
# <script>
#         cssVars({})
#     </script>
# </body>
# </html>>

# %%
listings = soup.find('div', id="event-listing")
print(listings)
# Out:
# <div class="fl col4" id="event-listing">
# <ul class="list" id="items">
# <li><p class="eventDate date"><a href="/events.aspx?ai=411&amp;v=day&amp;mn=2&amp;yr=2020&amp;dy=6"><span>Thu, 06 Feb 2020 /</span></a></p></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-02-06T00:00" itemprop="startDate">2020-02-06T00:00</time></span><a href="/events/1375259"><img height="76" src="/images/events/flyer/2020/2/us-0206-1375259-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1375259" itemprop="url" title="Event details of Field Trip 106: Dustycloud">Field Trip 106: Dustycloud</a> <span>at <a href="/club.aspx?id=68203">Q Nightclub</a>, <a href="/events.aspx?ai=46">Seattle</a></span></h1><div class="grey event-lineup">Dustycloud</div><p class="attending"><span>2</span> Attending</p></div></article></li><li><p class="eventDate date"><a href="/events.aspx?ai=411&amp;v=day&amp;mn=2&amp;yr=2020&amp;dy=7"><span>Fri, 07 Feb 2020 /</span></a></p></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-02-07T00:00" itemprop="startDate">2020-02-07T00:00</time></span><a href="/events/1363662"><img height="76" src="/images/events/flyer/2020/2/us-0207-1363662-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1363662" itemprop="url" title="Event details of Secondnature feat. Simo Cell">Secondnature feat. Simo Cell</a> <span>at <span class="grey" style="display:inline;">TBA - Seattle</span>, <a href="/events.aspx?ai=46">Seattle</a></span></h1><div class="grey event-lineup">Simo Cell, Ferg, Aos</div><p class="attending"><span>10</span> Attending</p></div></article></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-02-07T00:00" itemprop="startDate">2020-02-07T00:00</time></span><a href="/events/1374714"><img height="76" src="/images/events/flyer/2020/2/us-0207-1374714-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1374714" itemprop="url" title="Event details of Hunt &amp; Gather Winter Diversion: Doc Martin">Hunt &amp; Gather Winter Diversion: Doc Martin</a> <span>at <a href="/club.aspx?id=88733">Kremwerk</a>, <a href="/events.aspx?ai=46">Seattle</a></span></h1><div class="grey event-lineup">Doc Martin, Doza, Pezzner, Michael Manahan</div><p class="attending"><span>6</span> Attending</p></div></article></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-02-07T00:00" itemprop="startDate">2020-02-07T00:00</time></span><a href="/events/1373180"><img height="76" src="/images/events/flyer/2020/2/us-0207-1373180-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1373180" itemprop="url" title="Event details of Future Funktion V">Future Funktion V</a> <span>at <a href="/club.aspx?id=88733">Kremwerk</a>, <a href="/events.aspx?ai=46">Seattle</a></span></h1><div class="grey event-lineup">TIMBRE ROOM | Austin Robertson, Oxymoron, Parker Mills</div><p class="attending"><span>2</span> Attending</p></div></article></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-02-07T00:00" itemprop="startDate">2020-02-07T00:00</time></span><a href="/events/1375261"><img height="76" src="/images/events/flyer/2020/2/us-0207-1375261-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1375261" itemprop="url" title="Event details of Citrus Room 2-Year Anniversary: Sasha Marie">Citrus Room 2-Year Anniversary: Sasha Marie</a> <span>at <a href="/club.aspx?id=6 ...
# </ul>
# </div>

# %%
list_items = listings.find_all('li')
list_items
# Out:
# [<li><p class="eventDate date"><a href="/events.aspx?ai=411&amp;v=day&amp;mn=2&amp;yr=2020&amp;dy=6"><span>Thu, 06 Feb 2020 /</span></a></p></li>,
#  <li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-02-06T00:00" itemprop="startDate">2020-02-06T00:00</time></span><a href="/events/1375259"><img height="76" src="/images/events/flyer/2020/2/us-0206-1375259-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1375259" itemprop="url" title="Event details of Field Trip 106: Dustycloud">Field Trip 106: Dustycloud</a> <span>at <a href="/club.aspx?id=68203">Q Nightclub</a>, <a href="/events.aspx?ai=46">Seattle</a></span></h1><div class="grey event-lineup">Dustycloud</div><p class="attending"><span>2</span> Attending</p></div></article></li>,
#  <li><p class="eventDate date"><a href="/events.aspx?ai=411&amp;v=day&amp;mn=2&amp;yr=2020&amp;dy=7"><span>Fri, 07 Feb 2020 /</span></a></p></li>,
#  <li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-02-07T00:00" itemprop="startDate">2020-02-07T00:00</time></span><a href="/events/1363662"><img height="76" src="/images/events/flyer/2020/2/us-0207-1363662-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1363662" itemprop="url" title="Event details of Secondnature feat. Simo Cell">Secondnature feat. Simo Cell</a> <span>at <span class="grey" style="display:inline;">TBA - Seattle</span>, <a href="/events.aspx?ai=46">Seattle</a></span></h1><div class="grey event-lineup">Simo Cell, Ferg, Aos</div><p class="attending"><span>10</span> Attending</p></div></article></li>,
#  <li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-02-07T00:00" itemprop="startDate">2020-02-07T00:00</time></span><a href="/events/1374714"><img height="76" src="/images/events/flyer/2020/2/us-0207-1374714-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1374714" itemprop="url" title="Event details of Hunt &amp; Gather Winter Diversion: Doc Martin">Hunt &amp; Gather Winter Diversion: Doc Martin</a> <span>at <a href="/club.aspx?id=88733">Kremwerk</a>, <a href="/events.aspx?ai=46">Seattle</a></span></h1><div class="grey event-lineup">Doc Martin, Doza, Pezzner, Michael Manahan</div><p class="attending"><span>6</span> Attending</p></div></article></li>,
#  <li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-02-07T00:00" itemprop="startDate">2020-02-07T00:00</time></span><a href="/events/1373180"><img height="76" src="/images/events/flyer/2020/2/us-0207-1373180-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1373180" itemprop="url" title="Event details of Future Funktion V">Future Funktion V</a> <span>at <a href="/club.aspx?id=88733">Kremwerk</a>, <a href="/events.aspx?ai=46">Seattle</a></span></h1><div class="grey event-lineup">TIMBRE ROOM | Austin Robertson, Oxymoron, Parker Mills</div><p class="attending"><span>2</span> Attending</p></div></article></li>,
#  <li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-02-07T00:00" itemprop="startDate">2020-02-07T00:00</time></span><a href="/events/1375261"><img height="76" src="/images/events/flyer/2020/2/us-0207-1375261-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1375261" itemprop="url" title="Event details of Citrus Room 2-Year Anniversary: Sasha Marie">Citrus Room 2-Year Anniversary: Sasha Marie</a> <span>at <a href="/club.aspx?id=68203">Q Nightclub</a>, <a href="/events.aspx?ai=46">Seattle</a></span></h1><div class="grey event-lineup">Sasha Marie</div><p class="attending"><span>2</span> Attending</p></div></article></li>,
#  <li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-02-07T00:00" itemprop="startDate">2020-02-07T00:00</time></span><a href="/events/1374636"><img height="76" src="/images/events/flyer/2020/2/us-0207-1374636-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1374636" itemprop="url" title="Event details of Innerflight » Drop: DJ T. › Dubspeeka › Ben Annand › Rob Noble › Rhines › Night Train">Innerflight » Drop: DJ T. › Dubspeeka › Ben Annand › Rob Noble › Rhines › Night Train</a> <span>at <a href="/club.aspx?id=84493">The Monkey Loft</a>, <a href="/events.aspx?ai=46">Seattle</a></span></h1><div class="grey event-lineup">¤ DJ T, ¤ DUBSPEEKA, ¤ BEN ANNAND, ¤ ROB NOBLE, ¤ RHINES, ¤ NIGHT TRAIN</div><p class="attending"><span>1</span> Attending</p></div></article></li>,
#  <li><div class="but myra mt16" style="width: 152px;"><a href="/submit-event.aspx?ai=411">Submit event</a></div></li>,
#  <li><p class="eventDate date"><a href="/events.aspx?ai=411&amp;v=day&amp;mn=2&amp;yr=2020&amp;dy=8"><span>Sat, 08 Feb 2020 /</span></a></p></li>,
#  <li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-02-08T00:00" itemprop="startDate">2020-02-08T00:00</time></span><a href="/events/1377215"><img height="76" src="/images/events/flyer/2020/2/us-0208-1377215-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1377215" itemprop="url" title="Event details of Physical Wash, Lower Tar, Chrome Corpse, Leash, Vox Sinistra">Physical Wash, Lower Tar, Chrome Corpse, Leash, Vox Sinistra</a> <span>at <a href="/club.aspx?id=62614">Black Lodge</a>, <a href="/events.aspx?ai=46">Seattle</a></span></h1><div class="grey event-lineup"></div><p class="attending"><span>4</span> Attending</p></div></article></li>,
#  <li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-02-08T00:00" itemprop="startDate">2020-02-08T00:00</time></span><a href="/events/1378136"><img height="76" src="/images/events/flyer/2020/2/us-0208-1378136-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1378136" itemprop="url" title="Event details of Sundown: Enamour [Anjunadeep]">Sundown: Enamour [Anjunadeep]</a> <span>at <a href="/club.aspx?id=88733">Kremwerk</a>, <a href="/events.aspx?ai=46">Seattle</a></span></h1><div class="grey event-lineup">Enamour, Johnny Monsoon, Des, Web</div><p class="attending"><span>1</span> Attending</p></div></article></li>]

# %%
# if this evaluates to True then I know that this is an "event" item rather than a "date" item
list_items[1].find('p', class_="eventDate date") == None
# Out:
# True

# %%
# this above is missing the "submit event" item so I am going to change this measure the length of each string to find the real events

# %%
# all list items which are events will have string lengths greater than 30 (more like greater than 70)
details = list_items[7].text
len(details)
# Out:
# 211

# %%
date = details[0:16]
date
# Out:
# '2020-02-07T00:00'

# %%
other_details = details[16:]
other_details
# Out:
# 'Innerflight » Drop: DJ T. › Dubspeeka › Ben Annand › Rob Noble › Rhines › Night Train at The Monkey Loft, Seattle¤ DJ T, ¤ DUBSPEEKA, ¤ BEN ANNAND, ¤ ROB NOBLE, ¤ RHINES, ¤ NIGHT TRAIN1 Attending'

# %%
# prototype to find venue
venue = other_details.split(' at ')[1].split(',')[0]
venue
# Out:
# 'Black Lodge'

# %%
# prototype to find performer
performer = other_details.split(' at ')[0]
performer
# Out:
# 'Physical Wash, Lower Tar, Chrome Corpse, Leash, Vox Sinistra'

# %%
# how to find number attending???

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
rows = []
def scrape_events(events_page_url):
    html_page = requests.get(events_page_url)
    webpage = html_page.content
    soup = BeautifulSoup(webpage, "html.parser")
    listings = soup.find('div', id="event-listing")
    list_items = listings.find_all('li')
    for item in range(len(list_items)):
        details = list_items[item].text
        if len(details) > 30:
            date = details[0:16]
            other_details = details[16:]
            venue = other_details.split(' at ')[1].split(',')[0]
            performer = other_details.split(' at ')[0]
            rows.append([performer, date, venue])
        else:
            continue
    df = pd.DataFrame(rows)
    df.columns = ["Performer", "Date", "Venue"]
    return df

# %%
page_1 = scrape_events('https://www.residentadvisor.net/events/us/washingtonstate')

# %%
page_1
# Out:
#                                            Performer              Date  \
# 0                         Field Trip 106: Dustycloud  2020-02-06T00:00
# 1                       Secondnature feat. Simo Cell  2020-02-07T00:00
# 2         Hunt & Gather Winter Diversion: Doc Martin  2020-02-07T00:00
# 3                                  Future Funktion V  2020-02-07T00:00
# 4        Citrus Room 2-Year Anniversary: Sasha Marie  2020-02-07T00:00
# 5  Innerflight » Drop: DJ T. › Dubspeeka › Ben An...  2020-02-07T00:00
# 6  Physical Wash, Lower Tar, Chrome Corpse, Leash...  2020-02-08T00:00
# 7                      Sundown: Enamour [Anjunadeep]  2020-02-08T00:00
#
#              Venue
# 0      Q Nightclub
# 1    TBA - Seattle
# 2         Kremwerk
# 3         Kremwerk
# 4      Q Nightclub
# 5  The Monkey Loft
# 6      Black Lodge
# 7         Kremwerk

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
# create list of dates to be added to url at 1 week intervals
import datetime
numdays = 1000
base = datetime.date(2020,2,10)
date_list = [base + 7*datetime.timedelta(days=x) for x in range(numdays)]
date_list[0:5]
# Out:
# [datetime.date(2020, 2, 10),
#  datetime.date(2020, 2, 17),
#  datetime.date(2020, 2, 24),
#  datetime.date(2020, 3, 2),
#  datetime.date(2020, 3, 9)]

# %%
# prototype converting datetime object into string format for insertion into URL
date_list[0]
month = '{:02d}'.format(date_list[0].month) #convert day to two digit format
day = '{:02d}'.format(date_list[0].day) # convert month to two digit format
year = date_list[0].year
string_date = '{}-{}-{}'.format(year, month, day)
string_date
# Out:
# '2020-02-10'

# %%
# turn datetime list into list of string dates
string_dates = []
for i in range(len(date_list)):
    month = '{:02d}'.format(date_list[i].month)
    day = '{:02d}'.format(date_list[i].day)
    year = date_list[i].year
    string_date = '{}-{}-{}'.format(year, month, day)
    string_dates.append(string_date)

# %%
string_dates[0:5]
# Out:
# ['2020-02-10', '2020-02-17', '2020-02-24', '2020-03-02', '2020-03-09']

# %%
def next_page(url):
    #Your code here
    if url == 'https://www.residentadvisor.net/events/us/washingtonstate':
        next_page_url = 'https://www.residentadvisor.net/events/us/washingtonstate/week/2020-02-10'
    else: 
        url_string_date = url[-10:]
        date_index = string_dates.index(url_string_date) + 1
        next_page_url = 'https://www.residentadvisor.net/events/us/washingtonstate/week/' + string_dates[date_index]
    return next_page_url

# %%
list_of_urls = []
# there are only 9 pages with shows
for i in range(9):
    url = 'https://www.residentadvisor.net/events/us/washingtonstate/week/' + string_dates[i]
    list_of_urls.append(url)

list_of_urls
# Out:
# ['https://www.residentadvisor.net/events/us/washingtonstate/week/2020-02-10',
#  'https://www.residentadvisor.net/events/us/washingtonstate/week/2020-02-17',
#  'https://www.residentadvisor.net/events/us/washingtonstate/week/2020-02-24',
#  'https://www.residentadvisor.net/events/us/washingtonstate/week/2020-03-02',
#  'https://www.residentadvisor.net/events/us/washingtonstate/week/2020-03-09',
#  'https://www.residentadvisor.net/events/us/washingtonstate/week/2020-03-16',
#  'https://www.residentadvisor.net/events/us/washingtonstate/week/2020-03-23',
#  'https://www.residentadvisor.net/events/us/washingtonstate/week/2020-03-30',
#  'https://www.residentadvisor.net/events/us/washingtonstate/week/2020-04-06']

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
#Your code here
master_df = pd.DataFrame()

cum_len_dataframes = 0

while cum_len_dataframes <= 1000:
    for url in list_of_urls:
        df = scrape_events(url)
        master_df.append(df)
        cum_len_dataframes += len(df)

# %%
master_df
# why is this not working?????
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# testing other URL's.. This is pulling event names that aren't even in the source code for the URL
# for example try to find "DJ Seinfeld" in the source-code

df_x = scrape_events('https://www.residentadvisor.net/events/us/washingtonstate/week/2020-02-17')
df_x
# Out:
#                                              Performer              Date  \
# 0                           Field Trip 106: Dustycloud  2020-02-06T00:00
# 1                         Secondnature feat. Simo Cell  2020-02-07T00:00
# 2           Hunt & Gather Winter Diversion: Doc Martin  2020-02-07T00:00
# 3                                    Future Funktion V  2020-02-07T00:00
# 4          Citrus Room 2-Year Anniversary: Sasha Marie  2020-02-07T00:00
# ..                                                 ...               ...
# 110                                Haüsed: DJ Seinfeld  2020-02-20T00:00
# 111                          Field Trip 108: Dombresky  2020-02-20T00:00
# 112  Kremwerk 6 Year Anniversary Friday: Omar S [Re...  2020-02-21T00:00
# 113                              Pop Secret: Destructo  2020-02-21T00:00
# 114  Kremwerk 6 Year Aniversary Saturday: Shigeto, ...  2020-02-22T00:00
#
#              Venue
# 0      Q Nightclub
# 1    TBA - Seattle
# 2         Kremwerk
# 3         Kremwerk
# 4      Q Nightclub
# ..             ...
# 110       Kremwerk
# 111    Q Nightclub
# 112       Kremwerk
# 113    Q Nightclub
# 114       Kremwerk
#
# [115 rows x 3 columns]

# %%
# this is also pulling many duplicates
df_x.Performer.value_counts()
# Out:
# Pop Secret: Destructo                                                                              4
# Kremwerk 6 Year Anniversary Friday: Omar S [Research x Queer Dance Affair x Boyhood present]       4
# Haüsed: DJ Seinfeld                                                                                4
# Kremwerk 6 Year Aniversary Saturday: Shigeto, Jon Casey, Taso, Lefto [Shook & Soulfocus present    4
# Field Trip 108: Dombresky                                                                          4
# Telefon Tel Aviv                                                                                   3
# Bounce Brunch *Spring??* ft Tyler Morrison & Toastercookie                                         3
# Haüsed: Get Physical Takeover with Pezzner & Jon Lee                                               3
# Shameless 17 Year Anniversary Party with DeWalta & Residents                                       3
# Haüsed x Depth: La Fleur                                                                           3
# Pop Secret: Luca Lush                                                                              3
# Field Trip 114: Mercer                                                                             3
# Night School: Miami Horror DJs                                                                     3
# Yves Tumor & Its Band                                                                              3
# Field Trip 111: Malaa                                                                              3
# Field Trip 112: Odd Mob                                                                            3
# Fennesz, Britton Powell                                                                            3
# Ata Kak                                                                                            3
# Field Trip 110: Spencer Brown                                                                      3
# Tenth Aesthetic: Nick Carroll, Gag Reflex, Ol'skinny                                               3
# Tremulant: El Mundo & Zazou (Live)                                                                 3
# Haüsed: Flava D                                                                                    3
# Field Trip 109: Eli Brown                                                                          3
# Field Trip 116: Ben Bohmer (Live)                                                                  3
# Be Svendsen                                                                                        3
# Häused x Depth: Julian Jeweil [Drumcode]                                                           3
# Noise Complaint feat. Josh Wink + Two Nice Anniversary with Roska                                  3
# Depth: Aurora Halal with Archivist R.Pal B2B Todd Hochradel                                        3
# Noise Complaint feat. Will Clarke (Open-to-Close)                                                  3
# Field Trip 113: Wax Motif                                                                          3
# Haute Sauce: Falcons & Andre Power                                                                 3
# OS: Davis Galvin, DJ Illegit                                                                       3
# Monster Planet 10.WDE - Worst Date Ever: Chapter Ei8ht                                             3
# No Mana                                                                                            3
# Sundown: Enamour [Anjunadeep]                                                                      1
# Secondnature feat. Simo Cell                                                                       1
# Physical Wash, Lower Tar, Chrome Corpse, Leash, Vox Sinistra                                       1
# Innerflight » Drop: DJ T. › Dubspeeka › Ben Annand › Rob Noble › Rhines › Night Train              1
# Future Funktion V                                                                                  1
# Field Trip 106: Dustycloud                                                                         1
# Citrus Room 2-Year Anniversary: Sasha Marie                                                        1
# Hunt & Gather Winter Diversion: Doc Martin                                                         1
# Name: Performer, dtype: int64

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you successfully developed a pipeline to scrape a website for concert event information!
